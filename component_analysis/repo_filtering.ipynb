# %%
# !pwd
# Out:
# /Users/leoxu/codeground/MAS/component_analysis

# %%
import pandas as pd

# %%
data = pd.read_csv("data/github_repos_latest.csv")
data.head()
# Out:
#                                 full_name   stars  forks language  \
# 0                    sindresorhus/awesome  421010  32535      NaN
# 1                 public-apis/public-apis  383197  40898   Python
# 2                    vinta/awesome-python  272985  26872   Python
# 3   awesome-selfhosted/awesome-selfhosted  262088  12048      NaN
# 4  trimstray/the-book-of-secret-knowledge  197234  12043      NaN
#
#                                          description  \
# 0  😎 Awesome lists about all kinds of interesting...
# 1                     A collective list of free APIs
# 2  An opinionated list of awesome Python framewor...
# 3  A list of Free Software network services and w...
# 4  A collection of inspiring lists, manuals, chea...
#
#                                               topics            updated_at  \
# 0  awesome, awesome-list, lists, resources, unicorns  2025-12-08T20:36:46Z
# 1  api, apis, dataset, development, free, list, l...  2025-12-08T20:26:36Z
# ...
